# %% [markdown]
# # תרגיל מסכם matplotlib

# %% [markdown]
# ### יבאו את החבילה כ plt ותריצו את השורה שתגרום לגרפים להופיע אחרי יצירתם (אם אתם משתמשים ב jupyter)

# %% [markdown]
# ### ציירו את הגרף הלינארי y=x בתחום שבין 0 ל 10

# %%
import numpy as np

# %% [markdown]
# ### ציירו את הגרף הריבועי y=x^2 בתחום שבין 0 ל 10 (עבור x), בצבע אדום ותוסיפו את הכותרת "title"

# %%
# Out:
# Text(0.5, 1.0, 'title')

# %% [markdown]
# ### ציירו את הגרף y=x עם כוכבים בנקודות הנתונות, ובתוכו ציירו את הגרף y=3*x

# %% [markdown]
# ### ציירו את היסטוגרמת ההתפלגות של המשתנה x הנתון (x נוצר רנדומלית ואצלכם הוא יהיה שונה. לכן הגרף יראה אחרת)

# %%
import random

x = [random.randint(1, 10) for _ in range(100)]
# Out:
# (array([12.,  9., 12., 12.,  7., 10.,  8., 13.,  7., 10.]),
#  array([ 1. ,  1.9,  2.8,  3.7,  4.6,  5.5,  6.4,  7.3,  8.2,  9.1, 10. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### ציירו את היסטוגרמת ההתפלגות של המשתנה y הנתון

# %%
y = [random.randint(5, 10) for _ in range(100)]
# Out:
# (array([19.,  0., 18.,  0., 16.,  0., 18.,  0., 14., 15.]),
#  array([ 5. ,  5.5,  6. ,  6.5,  7. ,  7.5,  8. ,  8.5,  9. ,  9.5, 10. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### ציירו את גרף הקופסאות של x, y

# %%
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1688249bb50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x168824aa250>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1688249b7f0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x168824aa910>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x168824aac70>,
# ...
#  'means': []}

# %% [markdown]
# ### עבודה מעולה ! אתם מוכנים לעבור לפרק הבא, בו נלמד על Seaborn :)
