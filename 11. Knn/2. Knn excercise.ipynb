# %% [markdown]
# ### ברוכים הבאים לתרגיל המסכם של KNN. בתרגיל הזה נרצה לחזות, לפי מאפיינים של נשים, למי יש סרטן שד ולמי לא.
#
# ### נעשה זאת בעזרת אלגוריתם KNN, ושוב, כמו בתרגיל של הסוכרת, גם כאן נתעלם משמות המאפיינים.

# %% [markdown]
# ### ייבאו את החבילות sklearn, matplotlib, seaborn, pandas והריצו את השורה שגורמת לגרפים להופיע ב jupyter notebook

# %% [markdown]
# ### טענו את מאגר המידע breast-cancer.csv לתוך DataFrame בשם df.
# ### מאגר המידע נמצא בתיקייה notebooks/K Nearest Neighbors או מהאתר קאגל בכתובת:
# https://www.kaggle.com/uciml/breast-cancer-wisconsin-data

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %% [markdown]
# ### אין לנו NaN-ים, חוץ מהרשומה Unnamed: 32, שבה יש רק NaN-ים, ולא ברור מה היא בכלל עושה כאן. תוציאו אותה מ df.

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# ### בנוסף, תוציאו את מאפיין id, מכיוון שאין לו שום משמעות. כל המטרה של id היא שיהיה מספר ייחודי לכל רשומה, ויש לנו את זה כבר ב index של ה DataFrame.

# %%
df.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %% [markdown]
# ## data visualization
#
# #### שימו לב שכל המאפיינים הם מספריים, חוץ מהמאפיין diagnosis.
# #### היחס בין diagnosis לכל שאר המאפיינים הוא הדבר המרכזי שנרצה לבדוק. לכן, עלינו לשנות אותו לערכים מספריים.
# #### diagnosis הוא מאפיין המטרה.
#
# * M - malignant - ממאיר
# * B - benign - שפיר
#
# #### החליפו את M ב 1, ואת B ב 0.

# %%
df.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1        17.99         10.38          122.80     1001.0
# 1          1        20.57         17.77          132.90     1326.0
# 2          1        19.69         21.25          130.00     1203.0
# 3          1        11.42         20.38           77.58      386.1
# 4          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %% [markdown]
# ### האפשרות הקלה היא להציג את גרף ה pairplot של df, ולהסתכל בעיקר על השורה של diagnosis מול כל שאר המאפיינים, אך שימו לב שיש לנו 31 מאפיינים, מה שאומר שגרף ה pairplot של df יהיה בגודל 31 בריבוע, שזה מתקרב ל 1,000 גרפים.
#
# ### לכן, נסתכל רק על הגרפים שמעניינים אותנו - regplot של כל מאפיינן מול diagnosis.
# ### תיצרו 15 שורות, שבכל אחת מהן 2 גרפים. כל גרף יהיה regplot של diagnosis לעומת מאפיין אחר.
# ### רק הגרף של diagnosis לעומת diagnosis יהיה countplot

# %% [markdown]
# ### אפשר לראות שכמעט לכל המאפיינים יש קורלציה חיובית עם diagnosis. זאת אומרת שעבור כל המאפיינים, ככל שהערך גבוה יותר, כך גם הסיכוי לחלות גבוה יותר.
#
# ### בהתחשב בזה שאין ערכי NaN שצריך להשלים, ונראה שכל המאפיינים תורמים קורלציה אל מול מאפיין המטרה, אפשר פשוט להריץ את המודל. אל תתרגלו, ברוב המקרים מאגרי המידע עושים לנו הרבה יותר צרות.

# %% [markdown]
# ### חלקו את המידע ל X, Y

# %%
X.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
Y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: diagnosis, dtype: int64

# %% [markdown]
# ### השתמשו בפונקציה train_test_split כדי לחלק את המידע ל train, test.
#
# תריצו את הפונקציה כך שגודל ה train יהיה 80%, והשתמשו ב random_state=42 כדי שנקבל את אותה חלוקה.

# %%
from sklearn.model_selection import train_test_split

X_train.head()
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 68         9.029         17.33           58.79      250.5          0.10660
# 181       21.090         26.57          142.70     1311.0          0.11410
# 63         9.173         13.86           59.20      260.9          0.07721
# 248       10.650         25.22           68.01      347.0          0.09657
# 60        10.170         14.88           64.55      311.9          0.11340
#
#      compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 68            0.14130         0.31300              0.04375         0.2111
# 181           0.28320         0.24870              0.14960         0.2395
# 63            0.08751         0.05988              0.02180         0.2341
# 248           0.07234         0.02379              0.01615         0.1897
# 60            0.08061         0.01084              0.01290         0.2743
#
#      fractal_dimension_mean  ...  radius_worst  texture_worst  \
# ...

# %%
Y_train.head()
# Out:
# 68     0
# 181    1
# 63     0
# 248    0
# 60     0
# Name: diagnosis, dtype: int64

# %% [markdown]
# ### עכשיו נדמה מצב של חברת הייטק.
# ### נרצה לאמן מודל בעזרת כל המידע הקיים, שיפיק תוצאות טובות ככל האפשר על מידע שיגיע בעתיד.
# ### אפשר לחשוב על זה כאילו המידע שיגיע בעתיד הוא ה validation שבו השתמשנו בתרגיל הקודם.
# ### לכן, נרצה לאמן כמה מודלים על ה train, כל אחד עם K שונה, ולקחת את הטוב ביותר לפי הציונים על ה test.
# ### התוצאות שהמודל הטוב ביותר יגיעו אליו יהיו שקריות, כי יש כאן overfitting מסויים. ה K האופטימלי תלוי גם במאגר המידע וגם בחלוקה שלו.
#
# ### בואו נגיד שה K הטוב ביותר עבור מאגר המידע שלנו הוא 30. לכן, עבור חלוקה כלשהי, ה K הטוב ביותר שיתקבל יהיה באיזור ה 30, אבל רוב הסיכויים שהוא יזוז טיפה. נגיד ל 27.
#
# ### עכשיו, רוב הסיכויים שעבור מידע ה validation - המידע שיגיע בעתיד, ערך ה K האופטימלי לא יהיה בדיוק 27. נגיד שהוא יהיה 32. התוצאות עליו יהיו טיפה פחות מדויקות.
#
# ### העניין הוא, שאם קיבלנו ש 27 הוא ה K הכי מדוייק עבור מידע ה test, זה יהיה הניחוש הכי טוב שלנו עבור מידע ה validation, למרות שרוב הסיכויים שזה לא יהיה אופטימלי.
#
# ### זאת נקודה שיכולה לבלבל אנשים, והבנה שלה משמעה הבנה של תהליך הבנייה של כל מודל המשין לרנינג וחלוקת מידע. מי מכאן שקורא רק את המחברות, אשמח שהפעם תצפו בסרטון, שבו אסביר במילים את הכתוב למעלה.

# %% [markdown]
# ____

# %%
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# ### תאמנו מודל של KNeighborsClassifier עבור ערכי K בין 5 ל 30 עם קפיצות של 2, על מידע ה train, ותישמרו ברשימה את אחוז הטעויות עבור כל ערך של K

# %%
errors_percentage = [] # for each K, there will be the errors percentage on the test set.


errors_percentage
# Out:
# [0.043859649122807015,
#  0.043859649122807015,
#  0.043859649122807015,
#  0.017543859649122806,
#  0.02631578947368421,
#  0.03508771929824561,
#  0.03508771929824561,
#  0.03508771929824561,
#  0.03508771929824561,
#  0.043859649122807015,
#  0.05263157894736842,
#  0.05263157894736842,
#  0.05263157894736842]

# %% [markdown]
# ### הציגו גרף של אחוז הטעות לעומת ה K הנבחר. נקודות הערכים יהיו כוכבים.

# %% [markdown]
# ### קל לראות ש K=11 הוא הערך המתאים עבורנו. אמנו מודל עם K=11

# %%
# Out:
# KNeighborsClassifier(n_neighbors=11)

# %% [markdown]
# ### הציגו את ה classification_report עבור y_test והתחזית של המודל על X_test

# %%
from sklearn.metrics import classification_report
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99        71
#            1       1.00      0.95      0.98        43
#
#     accuracy                           0.98       114
#    macro avg       0.99      0.98      0.98       114
# weighted avg       0.98      0.98      0.98       114

# %% [markdown]
# ### אכן, אחוזי הדיוק מעולים. נזקוף את זה לכך שכמעט לכל המאפיינים יש קורלציה חיובית עם מאפיין המטרה, וגם כי בחרנו את ה K המתאים ביותר למידע ה test (קצת רמאות). מי שמעוניין יוכל לנסות ערכי K שונים ולראות את ההבדל בדיוק.
#
# ### כל הכבוד! נתראה בפרק הבא, בו נלמד על אלגוריתמים מבוססי עצים.
